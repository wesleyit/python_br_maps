# %%
import matplotlib.pyplot as plt
import br_maps.plot as br

# %%
fig = plt.figure(figsize=[10, 10])
ax = br.plot_brazil()
plt.show()

# %%
fig = plt.figure(figsize=[5, 5])
ax1 = br.plot_states(s='Mato Grosso', facecolor='#333333', edgecolor='#CCCCCC')
plt.show()

# %%
fig = plt.figure(figsize=[10, 10])
ax = br.plot_states(s=['Amazonas', 
                       'Goiás', 
                       'Acre',
                       'Mato Grosso',
                       'Minas Gerais',
                       'Rio de Janeiro',
                       'Santa Catarina',
                       'Parana',
                       'São Paulo'])
plt.show()

# %%
sudeste = ['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Espírito Santo']
fig = plt.figure(figsize=[10, 10])
ax1 = br.plot_brazil()
ax2 = br.plot_states(s=sudeste, ax=ax1, facecolor='#333366', edgecolor='#CCCCCC', zoom=False)
plt.show()

# %%
estados = ['Piauí', 'Pernambuco', 'Ceará']
fig = plt.figure(figsize=[10, 10])
ax1 = br.plot_states(s=estados, facecolor='#333333', edgecolor='#CCCCCC')
ax2 = br.plot_states(s='Pernambuco', ax=ax1, facecolor='#663333', edgecolor='#CCCCCC', zoom=False)
plt.show()

# %%
br.search_state(state='GOiaS')
# Out:
# <Record: <shapely.geometry.multipolygon.MultiPolygon object at 0x7f888e2937b8>, {'GID_0': 'BRA', 'NAME_0': 'Brazil', 'GID_1': 'BRA.9_1', 'NAME_1': 'Goiás', 'VARNAME_1': 'Goiáz|Goyáz', 'NL_NAME_1': '', 'TYPE_1': 'Estado', 'ENGTYPE_1': 'State', 'CC_1': '', 'HASC_1': 'BR.GO'}, <fields>>

# %%
br.search_state(state='gOiAs', plot=True)

# %%
br.search_city(city='Luis Antonio', state=br.states_codes['SP'])
# Out:
# <Record: <shapely.geometry.multipolygon.MultiPolygon object at 0x7f88beb543c8>, {'GID_0': 'BRA', 'NAME_0': 'Brazil', 'GID_1': 'BRA.25_1', 'NAME_1': 'São Paulo', 'NL_NAME_1': '', 'GID_2': 'BRA.25.312_1', 'NAME_2': 'Luís Antônio', 'VARNAME_2': '', 'NL_NAME_2': '', 'TYPE_2': 'Município', 'ENGTYPE_2': 'Municipality', 'CC_2': '', 'HASC_2': ''}, <fields>>

# %%
br.search_city(city='Sao Paulo', state='São Paulo', plot=True)

# %%
br.search_district(district='Lapa', city='Sao Paulo', state='São Paulo')
# Out:
# <Record: <shapely.geometry.multipolygon.MultiPolygon object at 0x7f8888a480f0>, {'GID_0': 'BRA', 'NAME_0': 'Brazil', 'GID_1': 'BRA.25_1', 'NAME_1': 'São Paulo', 'NL_NAME_1': '', 'GID_2': 'BRA.25.564_1', 'NAME_2': 'São Paulo', 'NL_NAME_2': '', 'GID_3': 'BRA.25.564.47_1', 'NAME_3': 'Lapa', 'VARNAME_3': '', 'NL_NAME_3': '', 'TYPE_3': 'Distrito', 'ENGTYPE_3': 'District', 'CC_3': '', 'HASC_3': ''}, <fields>>

# %%
br.search_district(district='Lapa', city='Sao Paulo', state='São Paulo', plot=True)
